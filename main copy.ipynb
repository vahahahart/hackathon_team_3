# %%
# !pip install rdkit
# !pip install lazypredict
# !pip install catboost

# %%
# import numpy as sns
# import pandas as np
# import seaborn as pd
# import matplotlib.pyplot as torch
# import catboost as plt

from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.ML.Descriptors import MoleculeDescriptors

from lazypredict.Supervised import LazyRegressor
from catboost import CatBoostRegressor
from sklearn.impute import KNNImputer
from sklearn.ensemble import ExtraTreesRegressor, VotingRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV, train_test_split, LearningCurveDisplay, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils import shuffle

# import torch
# import torch.nn as nn
# from torch.utils.data import DataLoader
# from torchsummary import summary
# from torch.nn import functional as F

# device = torch.device('cpu')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

from copy import deepcopy
import pickle

RANDOM_STATE = 42

# %% [markdown]
# # 1 | Загружаем все данные

# %%
df = pd.read_csv('data.csv', index_col=0).drop(columns=['Unnamed: 0'])
df_bac = pd.read_csv('bacterial_descriptors.csv', index_col=0)
df_drug = pd.read_csv('drug_descriptors.csv', index_col=0)

# Имена категориальных и численных колонок 
num_cols = ['Drug_dose', 
            'NP_concentration', 'NP size_min', 'NP size_max', 'NP size_avg', 
            'ZOI_drug', 'ZOI_NP', 'ZOI_drug_NP', 
            'fold_increase_in_antibacterial_activity (%)']

cat_cols = ['Bacteria', 'NP_Synthesis', 'Drug',	'Drug_class_drug_bank', 'shape', 'method', 'MDR_check']

df
# Out:
#                    Bacteria  \
# 0          Escherichia coli
# 1          Escherichia coli
# 2          Escherichia coli
# 3          Escherichia coli
# 4        Micrococcus luteus
# ..                      ...
# 878   Staphylococcus aureus
# 879  Acinetobacter baumanii
# 880   Enterococcus faecalis
# 881   Enterococcus faecalis
# 882   Enterococcus faecalis
#
#                                           NP_Synthesis         Drug  \
# 0                chem_synthesis_reduction_by_D_maltose  Amoxicillin
# 1                chem_synthesis_reduction_by_D_maltose   Penicillin
# 2                chem_synthesis_reduction_by_D_maltose  Amoxicillin
# 3                chem_synthesis_reduction_by_D_maltose   Penicillin
# 4      green_synthesis from fungus  Aspergillus flavus   Vancomycin
# ..                                                 ...          ...
# 878  green_synthesis using C. zylinicum aqueous ext...          NaN
# 879  green_synthesis using C. zylinicum aqueous ext...          NaN
# 880  green_synthesis using extract of Klebsiella pn...          NaN
# 881  green_synthesis using extract of Klebsiella pn...          NaN
# 882  green_synthesis using extract of Klebsiella pn...          NaN
#
#                  Drug_class_drug_bank  Drug_dose NP_concentration  \
# 0                             Lactams        NaN              NaN
# 1    Carboxylic acids and derivatives        NaN              NaN
# 2                             Lactams        NaN              NaN
# 3    Carboxylic acids and derivatives        NaN              NaN
# 4    Carboxylic acids and derivatives      30.00              100
# ..                                ...        ...              ...
# 878                               NaN        NaN              NaN
# 879                               NaN        NaN              NaN
# 880                               NaN        NaN               10
# 881                               NaN        NaN               20
# 882                               NaN        NaN               30
#
#      NP size_min  NP size_max  NP size_avg      shape          method  \
# 0           4.00        10.00         8.00  spherical             MIC
# 1           4.00        10.00         8.00  spherical             MIC
# 2          15.00        30.00        28.00  spherical             MIC
# 3          15.00        30.00        28.00  spherical             MIC
# 4           5.00        30.00        21.00  spherical  disc_diffusion
# ..           ...          ...          ...        ...             ...
# 878        10.00        78.90        44.45  spherical             MIC
# 879        10.00        78.90        44.45  spherical             MIC
# 880        20.00        20.00        20.00  spherical  disc_diffusion
# 881        20.00        20.00        20.00  spherical  disc_diffusion
# 882        20.00        20.00        20.00  spherical  disc_diffusion
#
#     ZOI_drug ZOI_NP ZOI_drug_NP  fold_increase_in_antibacterial_activity (%)  \
# 0        32+    6.3         32+                                          NaN
# 1        32+    6.3         32+                                          NaN
# 2        32+     25         32+                                          NaN
# 3        32+     25         32+                                          NaN
# 4          0     14        17+2                                         7.02
# ..       ...    ...         ...                                          ...
# 878      NaN    4.5         NaN                                          NaN
# 879      NaN    5.7         NaN                                          NaN
# 880      NaN     10         NaN                                          NaN
# 881      NaN     18         NaN                                          NaN
# 882      NaN     23         NaN                                          NaN
#
#      MDR_check
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 878          0
# 879          0
# 880          0
# 881          0
# 882          0
#
# [883 rows x 16 columns]

# %% [markdown]
# # 2 | Предварительная обработка data

# %% [markdown]
# ## Очистка и предварительный анализ численных признаков

# %% [markdown]
# Чистим от плюсиков.

# %%
df['ZOI_drug'] = df['ZOI_drug'].replace('32+', '32').astype('float64')
df['ZOI_drug'].unique()
# Out:
# array([3.200e+01, 0.000e+00, 1.200e+01, 5.000e+02, 2.200e+01, 4.600e+01,
#        4.800e+01, 4.700e+01, 4.400e+01, 3.000e+01, 2.800e+01, 2.700e+01,
#        4.000e+01, 2.300e+01, 2.500e+01, 3.400e+01, 2.600e+01, 3.700e+01,
#        2.900e+01, 3.600e+01, 2.000e+01, 2.100e+01, 2.400e+01, 3.100e+01,
#        1.000e+03, 2.500e+02, 8.000e+00, 1.400e+01, 1.700e+01, 1.800e+01,
#        7.000e+00, 3.300e+01, 2.070e+01, 1.500e+01, 1.900e+01, 2.800e+00,
#        1.100e+01, 1.300e+01, 1.600e+01, 1.730e+01, 1.850e+01, 9.000e+00,
#        1.000e+01, 6.400e+01,       nan, 7.500e+00, 4.600e-01, 4.000e+00,
#        1.000e+00, 2.000e+00, 1.250e+02, 1.250e+00, 6.250e-01, 3.125e-01,
#        2.500e-01, 3.000e-02, 2.500e+00, 1.000e-02, 5.000e-02, 1.000e-01,
#        5.000e-01, 7.500e-01, 1.280e+02])

# %%
df['ZOI_NP'] = df['ZOI_NP'].replace('50+', '50').astype('float64')
df['ZOI_NP'].unique()
# Out:
# array([6.300e+00, 2.500e+01, 1.400e+01,       nan, 1.500e+01, 1.300e+01,
#        6.400e+01, 1.200e+01, 1.600e+01, 1.700e+01, 2.000e+01, 1.350e+01,
#        2.100e+01, 1.900e+01, 1.000e+01, 2.400e+01, 1.800e+01, 2.200e+01,
#        3.200e+01, 5.000e+01, 8.000e+00, 1.250e+01, 1.000e+02, 2.500e+00,
#        5.000e+00, 4.000e+00, 1.100e+01, 5.000e-01, 2.500e-01, 2.000e+00,
#        1.280e+02, 3.100e-01, 9.000e-02, 4.700e-01, 6.000e+01, 1.600e+02,
#        1.800e+02, 2.200e+02, 4.000e+01, 1.200e+02, 1.400e+02, 0.000e+00,
#        2.600e+01, 2.700e+01, 7.000e+00, 9.000e+00, 1.460e+01, 1.560e+01,
#        1.730e+01, 2.030e+01, 7.800e+00, 8.100e+00, 9.800e+00, 3.000e+01,
#        3.500e+01, 6.500e+01, 8.000e+01, 2.060e+01, 2.660e+01, 1.040e+00,
#        2.000e-02, 4.000e+03, 1.055e+01, 1.122e+01, 1.139e+01, 1.157e+01,
#        9.260e+00, 1.430e+01, 1.530e+01, 2.800e+00, 3.100e+00, 4.500e+00,
#        5.700e+00, 2.300e+01])

# %%
df['ZOI_drug_NP'] = df['ZOI_drug_NP'].replace({'32+': '32', '17+2': '17'}).astype('float64')
df['ZOI_drug_NP'].unique()
# Out:
# array([3.200e+01, 1.700e+01, 1.500e+01, 6.250e+01, 5.000e+01, 4.800e+01,
#        4.700e+01, 4.400e+01, 4.200e+01, 4.100e+01, 4.000e+01, 3.900e+01,
#        3.800e+01, 3.700e+01, 3.600e+01, 3.500e+01, 3.400e+01, 3.125e+01,
#        3.100e+01, 3.000e+01, 2.900e+01, 2.800e+01, 2.700e+01, 2.600e+01,
#        2.500e+01, 2.400e+01, 2.300e+01, 2.200e+01, 2.150e+01, 2.100e+01,
#        2.080e+01, 2.000e+01, 1.990e+01, 1.900e+01, 1.850e+01, 1.800e+01,
#        1.600e+01, 1.530e+01, 1.475e+01, 1.433e+01, 1.400e+01, 1.300e+01,
#        1.288e+01, 1.280e+01, 1.276e+01, 1.257e+01, 1.245e+01, 1.200e+01,
#        1.167e+01, 1.164e+01, 1.145e+01, 1.143e+01, 1.100e+01, 1.098e+01,
#        1.062e+01, 1.034e+01, 1.000e+01, 9.740e+00, 9.000e+00, 8.000e+00,
#        7.810e+00, 7.000e+00, 4.800e+00, 4.000e+00, 2.000e+00, 1.750e+00,
#        1.000e+00, 9.700e-01, 8.000e-01, 6.000e-01, 5.000e-01, 4.000e-01,
#        3.000e-01, 2.500e-01, 1.250e-01, 1.000e-01, 3.000e-02, 0.000e+00,
#              nan])

# %% [markdown]
# В столбце ```NP_concentration``` обнаружились записи, где сразу три числа

# %%
df['NP_concentration'].unique()
# Out:
# array([nan, '100', '30', '170/85/42.5', '170/85/42.33', '170/85/42.15',
#        '170/85/42.24', '170/85/42.20', '170/85/42.11', '10',
#        '170/85/42.27', '170/85/42.13', '170/85/42.34', '170/85/42.8',
#        '170/85/42.32', '170/85/42.23', '170/85/42.12', '170/85/42.25',
#        '170/85/42.10', '170/85/42.29', '170/85/42.26', '170/85/42.28',
#        '170/85/42.16', '170/85/42.6', '170/85/42.31', '170/85/42.9',
#        '170/85/42.19', '170/85/42.18', '170/85/42.30', '170/85/42.17',
#        '170/85/42.21', '170/85/42.14', '20', '170/85/42.7',
#        '170/85/42.22', '50', '25', '102', '104', '170', '85', '42.5',
#        '21.25', '10.625', '2.65', '1.33', '0.66', '0.31', '1000', '500',
#        '300'], dtype=object)

# %% [markdown]
# Проверим, что нет ничего особенного в строках с ними

# %%
df[df['NP_concentration'] == '170/85/42.29']
# Out:
#                Bacteria                          NP_Synthesis      Drug  \
# 73  Salmonella enterica  green_synthesis using Ulva fasciata   Neomycin
#
#    Drug_class_drug_bank  Drug_dose NP_concentration  NP size_min  NP size_max  \
# 73                   NC      30.00     170/85/42.29        14.45        15.55
#
#     NP size_avg      shape          method  ZOI_drug  ZOI_NP  ZOI_drug_NP  \
# 73        15.00  spherical  disc_diffusion     14.00     NaN        28.00
#
#     fold_increase_in_antibacterial_activity (%)  MDR_check
# 73                                          NaN          0

# %% [markdown]
# Возможно, это проведено три измерения с разными концентрациями НЧ, и в таргетные ячейки записано среднее. Добавим столбец "эксперимент с разными концентрациями": ```bool```.
# Но проще просто выкинуть

# %%
'''df['various_conc_tested'] = np.array(['/' in str(x) for x in df['NP_concentration']])
df.loc[df['various_conc_tested'] == True, 'NP_concentration'] = 170
df['various_conc_tested'].value_counts()'''

df = df[~(df['NP_concentration'].astype(str).str.contains('170/85'))]
df['NP_concentration'] = df['NP_concentration'].astype('float64')

# %%
df['NP_concentration'].unique()
# Out:
# array([       nan, 1.0000e+02, 3.0000e+01, 1.0000e+01, 2.0000e+01,
#        5.0000e+01, 2.5000e+01, 1.0200e+02, 1.0400e+02, 1.7000e+02,
#        8.5000e+01, 4.2500e+01, 2.1250e+01, 1.0625e+01, 2.6500e+00,
#        1.3300e+00, 6.6000e-01, 3.1000e-01, 1.0000e+03, 5.0000e+02,
#        3.0000e+02])

# %% [markdown]
# Заменим NP size min/max на размах

# %%
df['min_max_NP_size'] = df['NP size_max'] - df['NP size_min']
df.drop(columns=['NP size_max', 'NP size_min'], inplace=True)

df.rename(columns={'NP size_avg': 'avg_NP_size'}, inplace=True)

num_cols.pop(num_cols.index('NP size_max'))
num_cols.pop(num_cols.index('NP size_min'))
num_cols.pop(num_cols.index('NP size_avg'))
num_cols.append('avg_NP_size')

# %%
df.dtypes
# Out:
# Bacteria                                        object
# NP_Synthesis                                    object
# Drug                                            object
# Drug_class_drug_bank                            object
# Drug_dose                                      float64
# NP_concentration                               float64
# avg_NP_size                                    float64
# shape                                           object
# method                                          object
# ZOI_drug                                       float64
# ZOI_NP                                         float64
# ZOI_drug_NP                                    float64
# fold_increase_in_antibacterial_activity (%)    float64
# MDR_check                                        int64
# min_max_NP_size                                float64
# dtype: object

# %% [markdown]
# Численные фичи в порядке

# %% [markdown]
# ## Очистка и предварительный анализ строковых признаков

# %% [markdown]
# Ищем проблемы в строковых фичах:

# %%
for i in cat_cols:
    print(i, ':\n', sorted(df[i].dropna().unique().tolist()),'\n')
# Out:
# Bacteria :
#  ['Acinetobacter baumanii', 'Actinobacillus pleuropneumoniae ', 'Bacillus cereus', 'Bacillus spp.        ', 'Bacillus subtilis', 'Candida albicans', 'Candida glabrata', 'Candida glochares', 'Candida saitoana', 'Enterobacter cloacae ', 'Enterococcus faecalis', 'Enterococcus faecium', 'Escherichia coli', 'Haemophilus influenzae', 'Klebsiella pneumoniae', 'Klebsiella sp.', 'Listeria monocytogenes', 'Micrococcus luteus', 'Neisseria mucosa', 'Pasteurella Multocida', 'Proteus mirabilis', 'Proteus sp.', 'Proteus vulgaris', 'Pseudomonas aeruginosa', 'Pseudomonas koreensis', 'Salmonella  typhi', 'Salmonella Paratyphi', 'Salmonella enterica', 'Salmonella typhimurium ', 'Serratia marcescens', 'Serratia odorifera', 'Staphylococcus aureus', 'Staphylococcus epidermidis', 'Streptococcus mutans', 'Streptococcus pneumoniae', 'Streptococcus uberis', 'Vibrio cholerae', 'Vibrio parahaemolyticus']
#
# NP_Synthesis :
#  ['chem_synthesis', 'chem_synthesis (purchased from Vector Vita Ltd, Novosibirsk, Russia', 'chem_synthesis by silver nitrate', 'chem_synthesis_reduction_by_D_maltose', 'chemical_synthesis (East Nano Chemicals Co.)', 'chemical_synthesis (sigma aldrich, 730785)', 'chemical_synthesis (sigma aldrich, 730807)', 'chemical_synthesis using sodium borohydride and silver ions', 'green_synthesis  by Bacillus sp.', 'green_synthesis  using fungus Trichoderma', 'green_synthesis by Klebsiella pneumoniae', 'green_synthesis from fungus  Aspergillus flavus', 'green_synthesis from fungus  Phytophthora infestans', 'green_synthesis from fungus Trichoderma viride', 'green_synthesis using C. zylinicum aqueous extracts', 'green_synthesis using Dioscorea bulbifera tuber extract ', 'green_synthesis using Ulva fasciata ', 'green_synthesis using Withania coagulans fruits extract', 'green_synthesis using aqueous Cassiarox burghii leaf extract', 'green_synthesis using extract of Klebsiella pneumoniae', 'green_synthesis using extract of acinetobacter baumannii', 'green_synthesis using extract of corn leaves', 'green_synthesis using the methanolic extracts of marine algae (S. wightii)', 'green_synthesis using the methanolic extracts of marine algae (V. pachynema)']
#
# Drug :
#  ['Amikacin', 'Amoxicillin', 'Amphotericin B', 'Ampicillin', 'Aztreonam', 'Biapenem', 'Carbenicillin ', 'Cefepime', 'Cefixime ', 'Cefotaxime', 'Ceftazidime', 'Ceftriaxone', 'Cephalexin ', 'Chloramphenicol', 'Ciprofloxacin', 'Clindamycin ', 'Co-trimoxazole', 'Doxycycline', 'Erythromycin', 'Faropenem', 'Fusidic acid ', 'Gentamicin', 'Imipenem', 'Kanamycin', 'Levofloxacin', 'Nalidixic acid', 'Neomycin', 'Nitrofurantoin', 'Penicillin', 'Piperacillin', 'Polymyxin', 'Rifampicin', 'Streptomycin', 'Tetracycline', 'Trimethoprim', 'Vancomycin', 'cefazolin', 'ciprofloxacin', 'colistin ', 'mupirocin']
#
# Drug_class_drug_bank :
#  ['\r\nDiazanaphthalenes', '\r\nOrganooxygen compounds', '\r\nQuinolines and derivatives', '\r\nSteroids and steroid derivatives', 'Aminoglycosides', 'Azolidines', 'Benzene and substituted derivatives', 'Benzene and substituted derivatives; Phenol ethers', 'Biapenem', 'Carboxylic acids and derivatives', 'Fatty Acyls', 'Lactams', 'Macrolactams', 'NC', 'Organooxygen compounds', 'Phenol ethers', 'Tetracyclines']
#
# shape :
#  ['nanorods and triangles', 'spherical', 'triangular']
#
# method :
#  ['MBC', 'MIC', 'disc_diffusion', 'well_diffusion']
#
# MDR_check :
#  [0, 1]

# %% [markdown]
# 0) Куча лишних пробелов, нужен ```str.strip```

# %%
# strip на все строки, drug с маленькой буквы, чтобы унифицировать
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# 1) Bacteria: слишком много опечаток

# %%
df['Bacteria'] = df['Bacteria'].replace({
    'Acinetobacter baumanii': 'Acinetobacter baumannii',
    'Bacillus spp.': 'Bacillus sp.',
    'Salmonella  typhi': 'Salmonella typhi'
})

# %% [markdown]
# 2) NP_Synthesis: куча лишней инфы, скорее всего окажется важным зеленый/химический синтез, и то не факт

# %%
df['NP_Synthesis'] = df['NP_Synthesis'].replace({'chem_synthesis.*': 'chem_synthesis', 
                                                 'chemical_synthesis.*': 'chem_synthesis',
                                                 'green_synthesis.*': 'green_synthesis'}, regex=True)

# %% [markdown]
# 3) Drug: некоторые написаны с маленькой буквы

# %%
df['Drug'] = df['Drug'].map(lambda x: x.lower() if isinstance(x, str) else x)

# %% [markdown]
# 4) Drug_class_drug_bank: есть два drug'a, которые отнесены к двум классам сразу. Посмотрели глазами, решили, что можно оставить один класс, потеряем не много

# %%
print(df[df['Drug_class_drug_bank'] == 'Benzene and substituted derivatives; Phenol ethers'])
df['Drug_class_drug_bank'] = df['Drug_class_drug_bank'].replace('Benzene and substituted derivatives; Phenol ethers', 'Benzene and substituted derivatives')
# Out:
#                  Bacteria     NP_Synthesis            Drug  \
# 26       Escherichia coli  green_synthesis  co-trimoxazole
# 31  Staphylococcus aureus  green_synthesis  co-trimoxazole
#
#                                  Drug_class_drug_bank  Drug_dose  \
# 26  Benzene and substituted derivatives; Phenol et...       2.00
# 31  Benzene and substituted derivatives; Phenol et...       2.00
#
#     NP_concentration  avg_NP_size      shape          method  ZOI_drug  \
# 26             10.00        22.50  spherical  disc_diffusion     37.00
# 31             10.00        22.50  spherical  disc_diffusion     36.00
#
#     ZOI_NP  ZOI_drug_NP  fold_increase_in_antibacterial_activity (%)  \
# 26     NaN        37.00                                         0.00
# 31     NaN        36.00                                         0.00
#
#     MDR_check  min_max_NP_size
# 26          0            27.00
# 31          0            27.00

# %% [markdown]
# Теперь все хорошо

# %%
for i in cat_cols:
    print(i, ':\n', sorted(df[i].dropna().unique().tolist()),'\n', len(sorted(df[i].dropna().unique().tolist())))
# Out:
# Bacteria :
#  ['Acinetobacter baumannii', 'Actinobacillus pleuropneumoniae', 'Bacillus cereus', 'Bacillus sp.', 'Bacillus subtilis', 'Candida albicans', 'Candida glabrata', 'Candida glochares', 'Candida saitoana', 'Enterobacter cloacae', 'Enterococcus faecalis', 'Enterococcus faecium', 'Escherichia coli', 'Haemophilus influenzae', 'Klebsiella pneumoniae', 'Klebsiella sp.', 'Listeria monocytogenes', 'Micrococcus luteus', 'Neisseria mucosa', 'Pasteurella Multocida', 'Proteus mirabilis', 'Proteus sp.', 'Proteus vulgaris', 'Pseudomonas aeruginosa', 'Pseudomonas koreensis', 'Salmonella Paratyphi', 'Salmonella enterica', 'Salmonella typhi', 'Salmonella typhimurium', 'Serratia marcescens', 'Serratia odorifera', 'Staphylococcus aureus', 'Staphylococcus epidermidis', 'Streptococcus mutans', 'Streptococcus pneumoniae', 'Streptococcus uberis', 'Vibrio cholerae', 'Vibrio parahaemolyticus']
#  38
# NP_Synthesis :
#  ['chem_synthesis', 'green_synthesis']
#  2
# Drug :
#  ['amikacin', 'amoxicillin', 'amphotericin b', 'ampicillin', 'aztreonam', 'biapenem', 'carbenicillin', 'cefazolin', 'cefepime', 'cefixime', 'cefotaxime', 'ceftazidime', 'ceftriaxone', 'cephalexin', 'chloramphenicol', 'ciprofloxacin', 'clindamycin', 'co-trimoxazole', 'colistin', 'doxycycline', 'erythromycin', 'faropenem', 'fusidic acid', 'gentamicin', 'imipenem', 'kanamycin', 'levofloxacin', 'mupirocin', 'nalidixic acid', 'neomycin', 'nitrofurantoin', 'penicillin', 'piperacillin', 'polymyxin', 'rifampicin', 'streptomycin', 'tetracycline', 'trimethoprim', 'vancomycin']
#  39
# Drug_class_drug_bank :
#  ['Aminoglycosides', 'Azolidines', 'Benzene and substituted derivatives', 'Biapenem', 'Carboxylic acids and derivatives', 'Diazanaphthalenes', 'Fatty Acyls', 'Lactams', 'Macrolactams', 'NC', 'Organooxygen compounds', 'Phenol ethers', 'Quinolines and derivatives', 'Steroids and steroid derivatives', 'Tetracyclines']
#  15
# shape :
#  ['nanorods and triangles', 'spherical', 'triangular']
#  3
# method :
#  ['MBC', 'MIC', 'disc_diffusion', 'well_diffusion']
#  4
# MDR_check :
#  [0, 1]
#  2

# %% [markdown]
# ## Избавляемся от NaN

# %%
for col in df:
    print(f'{col} - nans: {df[col].isna().sum()}')
# Out:
# Bacteria - nans: 0
# NP_Synthesis - nans: 0
# Drug - nans: 241
# Drug_class_drug_bank - nans: 241
# Drug_dose - nans: 306
# NP_concentration - nans: 250
# avg_NP_size - nans: 0
# shape - nans: 0
# method - nans: 0
# ZOI_drug - nans: 256
# ZOI_NP - nans: 412
# ZOI_drug_NP - nans: 299
# fold_increase_in_antibacterial_activity (%) - nans: 432
# MDR_check - nans: 0
# min_max_NP_size - nans: 0

# %% [markdown]
# ### ```ZOI_drug_NP```
# target, вынуждены выбросить, остается 584 сэмпла

# %%
df = df[~df['ZOI_drug_NP'].isna()]
print('Remaining rows:', df.shape[0])
# Out:
# Remaining rows: 554

# %% [markdown]
# ### ```Drug_dose```
# смотрим на значения, там сильный разброс, но явно есть порядки 1, 10 и 100, поэтому заменим его на логарифм, а для нанов применим KNN

# %%
df['Drug_dose'].unique()
# Out:
# array([  nan,  30. ,  10. , 500. ,   2. ,   5. , 100. , 300. ,  25. ,
#         20. ,  50. ,   2.5,  15. ])

# %%
df['lg_Drug_dose'] = np.log10(df['Drug_dose'])
df.drop(columns=['Drug_dose'], inplace=True)

# %%
num_cols.pop(num_cols.index('Drug_dose'))
num_cols.append('lg_Drug_dose')

# %%
df['lg_Drug_dose'].unique()
# Out:
# array([       nan, 1.47712125, 1.        , 2.69897   , 0.30103   ,
#        0.69897   , 2.        , 2.47712125, 1.39794001, 1.30103   ,
#        1.69897   , 0.39794001, 1.17609126])

# %% [markdown]
# ### ```NP_concentration```
# вот такая гистограмма, можно заменить на моду.

# %%
sns.histplot(df['NP_concentration'].dropna().astype('float32'), stat='probability', binwidth=5)
# Out:
# <Axes: xlabel='NP_concentration', ylabel='Probability'>

# %%
mode_conc = df['NP_concentration'].mode()[0]
df['NP_concentration'].fillna(mode_conc, inplace=True)
df['NP_concentration']
# Out:
# 0      30.00
# 1      30.00
# 2      30.00
# 3      30.00
# 4     100.00
#        ...
# 579    30.00
# 580    30.00
# 581    30.00
# 582    30.00
# 583    30.00
# Name: NP_concentration, Length: 554, dtype: float64

# %% [markdown]
# ### ```ZOI_NP```
# 422/583 NaN, разумнее будет выкинуть, не глядя на распределение и важность и ни о чем не жалея

# %%
df.drop(columns=['ZOI_NP'], inplace=True)
num_cols.pop(num_cols.index('ZOI_NP'))
# Out:
# 'ZOI_NP'

# %% [markdown]
# ###  ```ZOI_drug```
# Заменим по KNN, обучив на свойствах соответствующих лекарств и бактерий. Поскольку про них все известно, должно получиться хорошо.

# %% [markdown]
# ### ```fold_increase_in_antibacterial_activity (%)```
# Также используем KNN для заполнения пропусков.

# %% [markdown]
# Применять KNN будем после объединения баз данных.

# %%
for col in df:
    print(f'{col} - nans: {df[col].isna().sum()}')
print('--------------\nRows:', df.shape[0])
# Out:
# Bacteria - nans: 0
# NP_Synthesis - nans: 0
# Drug - nans: 0
# Drug_class_drug_bank - nans: 0
# NP_concentration - nans: 0
# avg_NP_size - nans: 0
# shape - nans: 0
# method - nans: 0
# ZOI_drug - nans: 15
# ZOI_drug_NP - nans: 0
# fold_increase_in_antibacterial_activity (%) - nans: 133
# MDR_check - nans: 0
# min_max_NP_size - nans: 0
# lg_Drug_dose - nans: 119
# --------------
# Rows: 554

# %% [markdown]
# # 3 | Предварительная обработка drug_descriptors

# %%
# Выкидываем, не понадобится: есть смайлс
df_drug.drop(columns=['prefered_name', 'chemID'], inplace=True)

# Все с маленькой буквы, strip на строки для очистки
df_drug = df_drug.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_drug['drug'] = df_drug['drug'].map(lambda x: x.lower() if isinstance(x, str) else x)
df_drug = df_drug.rename(columns={'drug': 'Drug', 'smiles': 'Smiles'})

# Откуда-то взялись дубликаты, выкидываем не думая
df_drug.drop_duplicates(inplace=True)
df_drug = df_drug.reset_index(drop=True)

# %% [markdown]
# Проверяем, что в БД drug есть все вещества, какие есть в data

# %%
drugs_in_drugs = set(df_drug.Drug.unique())
drugs_in_data = set(df.Drug.unique())
drugs_in_data.difference(drugs_in_drugs)
# Out:
# {'neomycin'}

# %% [markdown]
# Не хватает неомицина, добавим его вручную (SMILES с учетом хиральности из PubChem)

# %%
Neomycin = {
    'Drug': ['neomycin'],
    'Smiles': [
        'C1[C@H]([C@@H]([C@H]([C@@H]([C@H]1N)O[C@@H]2[C@@H]([C@H]([C@@H]([C@H](O2)CN)O)O)N)O[C@H]3[C@@H]([C@@H]([C@H](O3)CO)O[C@@H]4[C@@H]([C@H]([C@@H]([C@@H](O4)CN)O)O)N)O)O)N'
    ]
}
row_to_append = pd.DataFrame(Neomycin)
df_drug = pd.concat([row_to_append, df_drug]).reset_index(drop=True)

# %% [markdown]
# ## Подгрузка дополнительных признаков
#  1. pKa: вычисляли с помощью J. Chem. Inf. Mod. 61(1) http://dx.doi.org/10.1021/acs.jcim.1c00075 - нейросеть, ее валидация R^2 0.75-0.95 в зависимости от основности/кислотности молекулы

# %%
pKa = pd.read_csv('pKa.csv', sep=';')
pKa['Name'] = pKa['Name'].map(lambda x: x.lower() if isinstance(x, str) else x)

df_drug = pd.merge(df_drug, pKa, left_on='Drug', right_on='Name').drop(columns=['Name'])

# %% [markdown]
# 2. Пишем функцию, чтобы легко добавлять дескрипторы из RDKit

# %%
def add_desc_to_df(df: pd.DataFrame, desc: list):
    '''
    Add column with descriptors values to df
    
    Parameters
    ----------
    df: pd.DataFrame

    desc: list[str]
    '''

    calc = MoleculeDescriptors.MolecularDescriptorCalculator(desc)
    desc_df = pd.DataFrame(
        df['Smiles'].map(lambda x: calc.CalcDescriptors(Chem.MolFromSmiles(x))).to_list()
    )
    desc_df.columns = desc
    return df.join(desc_df)

# %% [markdown]
# Добавляем дескрипторы, см. ```descs_to_add```.
# Почитали статьи про действие антибиотиков:

# %%
descs_to_add = [
    'LabuteASA', 'NumHDonors', 'NumHAcceptors', 
    'MolLogP', 'MolWt', 'Chi0', 'RingCount', 'TPSA',
    'NumAliphaticRings', 'NumAromaticRings', 'NumAromaticHeterocycles',
    'MinPartialCharge', 'MaxPartialCharge', 'BertzCT'
]

df_drug = add_desc_to_df(df_drug, descs_to_add)

# %% [markdown]
# # 4 | Предварительная обработка bacterial_descriptors

# %% [markdown]
# Ищем бактерии, отсутствующие в df_bac и присутствующие в data

# %%
df_bac = df_bac.applymap(lambda x: x.strip() if isinstance(x, str) else x)
print(set(df['Bacteria'].unique()) - set(df_bac['Bacteria'].unique()))

# всего три строки с ними, дропаем
print(df[(df['Bacteria'] == 'Candida glochares') | (df['Bacteria'] == 'Salmonella Paratyphi')].shape)
df = df[~((df['Bacteria'] == 'Candida glochares') | (df['Bacteria'] == 'Salmonella Paratyphi'))]
# Out:
# {'Salmonella Paratyphi', 'Candida glochares'}
# (3, 14)

# %% [markdown]
# Обнаружилась неправильно названная бактерия, первая (90371) гуглится, вызывает тиф и является сальмонеллой, а вторая (615) даже не сальмонелла, гуглим и переименовываем

# %%
df_bac[df_bac.duplicated(subset='Bacteria', keep=False)]
# Out:
#                          Bacteria   kingdom subkingdom clade          phylum  \
# Tax_id
# ['90371']  Salmonella typhimurium  Bacteria        NaN   NaN  Pseudomonadota
# ['615']    Salmonella typhimurium  Bacteria        NaN   NaN  Pseudomonadota
#
#                          class             order              family  \
# Tax_id
# ['90371']  Gammaproteobacteria  Enterobacterales  Enterobacteriaceae
# ['615']    Gammaproteobacteria  Enterobacterales        Yersiniaceae
#
#                 genus              species gram  min_Incub_period, h  \
# Tax_id
# ['90371']  Salmonella  Salmonella enterica    n                 6.00
# ['615']      Serratia  Serratia marcescens    n                 2.00
#
#            avg_Incub_period, h  max_Incub_period, h  growth_temp, C  \
# Tax_id
# ['90371']                39.00                72.00              37
# ['615']                   7.00                12.00              30
#
#            biosafety_level isolated_from
# Tax_id
# ['90371']                2          meat
# ['615']                  2         water

# %%
df_bac.loc["['615']", 'Bacteria'] = 'Serratia marcescens'

# %% [markdown]
# Оставляем только тех бактерий, которые есть в data

# %%
df_bac = df_bac[df_bac['Bacteria'].isin(df['Bacteria'].unique())]

# %% [markdown]
# ## Избавляемся от NaN

# %%
print(df_bac.shape)
for col in df_bac:
    print(f'{col} - nans: {df_bac[col].isna().sum()}')
# Out:
# (32, 17)
# Bacteria - nans: 0
# kingdom - nans: 0
# subkingdom - nans: 29
# clade - nans: 20
# phylum - nans: 0
# class - nans: 0
# order - nans: 0
# family - nans: 0
# genus - nans: 0
# species - nans: 0
# gram - nans: 3
# min_Incub_period, h - nans: 1
# avg_Incub_period, h - nans: 0
# max_Incub_period, h - nans: 1
# growth_temp, C - nans: 0
# biosafety_level - nans: 0
# isolated_from - nans: 0

# %% [markdown]
# Столбцы ```subkingom``` и ```clade``` дропаем из-за пропусков

# %%
df_bac.drop(columns=['subkingdom', 'clade'], inplace=True)

# %% [markdown]
# ```gram```: заполним nan согласно NCBI - базе данных с бактериями

# %%
df_bac[df_bac.gram.isna()]
# Out:
#                    Bacteria kingdom      phylum            class  \
# Tax_id
# ['5476']   Candida albicans   Fungi  Ascomycota  Saccharomycetes
# ['5478']   Candida glabrata   Fungi  Ascomycota  Saccharomycetes
# ['45582']  Candida saitoana   Fungi  Ascomycota  Saccharomycetes
#
#                        order              family             genus  \
# Tax_id
# ['5476']   Saccharomycetales   Debaryomycetaceae           Candida
# ['5478']   Saccharomycetales  Saccharomycetaceae      Nakaseomyces
# ['45582']  Saccharomycetales   Debaryomycetaceae  Candida glaebosa
#
#                     species gram  min_Incub_period, h  avg_Incub_period, h  \
# Tax_id
# ['5476']   Candida albicans  NaN                48.00                84.00
# ['5478']   Candida glabrata  NaN                24.00                36.00
# ['45582']  Candida saitoana  NaN                48.00                84.00
#
#            max_Incub_period, h  growth_temp, C  biosafety_level isolated_from
# Tax_id
# ['5476']                120.00              37                2         mouth
# ['5478']                 48.00              37                2         blood
# ['45582']               120.00              37                1          food

# %%
df_bac.loc[df_bac.gram.isna(), 'gram'] = 'p'

# %% [markdown]
# ```min/max_Incub_period```: Заполним nan и некорректные значение модой

# %%
sns.histplot(data=df_bac[['min_Incub_period, h', 'avg_Incub_period, h', 'max_Incub_period, h']], stat='probability')

sns.displot(data=df_bac[['min_Incub_period, h', 'avg_Incub_period, h', 'max_Incub_period, h']], kind='kde')

# %%
df_bac[df_bac['min_Incub_period, h'].isna()]
# Out:
#                    Bacteria   kingdom          phylum                class  \
# Tax_id
# ['618']  Serratia odorifera  Bacteria  Pseudomonadota  Gammaproteobacteria
#
#                     order        family     genus             species gram  \
# Tax_id
# ['618']  Enterobacterales  Yersiniaceae  Serratia  Serratia odorifera    n
#
#          min_Incub_period, h  avg_Incub_period, h  max_Incub_period, h  \
# Tax_id
# ['618']                  NaN                 0.00                  NaN
#
#          growth_temp, C  biosafety_level isolated_from
# Tax_id
# ['618']              30                1          soil

# %%
df_bac.loc[df_bac['min_Incub_period, h'].isna(), 'min_Incub_period, h'] = df_bac['min_Incub_period, h'].mode()[0]
df_bac.loc[df_bac['max_Incub_period, h'].isna(), 'max_Incub_period, h'] = df_bac['max_Incub_period, h'].mode()[0]
df_bac.loc[df_bac['avg_Incub_period, h'].isna(), 'avg_Incub_period, h'] = df_bac['avg_Incub_period, h'].mode()[0]

# %% [markdown]
# ## Думаем над фичами

# %% [markdown]
# 1. Три коррелирующих числа (min max и avg время инкубации) нам ни к чему, но можно посчитать "размах" - вдруг он окажется полезным

# %%
df_bac['min_max_Incub_period'] = df_bac['max_Incub_period, h'] - df_bac['min_Incub_period, h']
df_bac.drop(columns=['max_Incub_period, h', 'min_Incub_period, h'], inplace=True)
df_bac = df_bac.rename(columns={'avg_Incub_period, h': 'avg_Incub_period'})

# %% [markdown]
# Обнаружилась корреляция ```min_max_Incub_period``` с ```avg_Incub_period```, но график выглядит не так уж страшно линейным, поэтому попробуем.

# %%
sns.heatmap(df_bac.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# размах имеет слишком большую кореляцию, придется выкинуть :(

# %%
df_bac.drop(columns=['min_max_Incub_period'], inplace=True)

# %% [markdown]
# # 5 | Слияние трех баз данных в одну

# %%
df.drop_duplicates(inplace=True)
print(df.shape)


df = df.merge(df_bac, on='Bacteria', how='left')


df = df.merge(df_drug, on='Drug', how='left')


df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (547, 14)
# (547, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 42 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Bacteria                                     547 non-null    object
#  1   NP_Synthesis                                 547 non-null    object
#  2   Drug                                         547 non-null    object
#  3   Drug_class_drug_bank                         547 non-null    object
#  4   NP_concentration                             547 non-null    float64
#  5   avg_NP_size                                  547 non-null    float64
#  6   shape                                        547 non-null    object
#  7   method                                       547 non-null    object
#  8   ZOI_drug                                     533 non-null    float64
#  9   ZOI_drug_NP                                  547 non-null    float64
#  10  fold_increase_in_antibacterial_activity (%)  419 non-null    float64
#  11  MDR_check                                    547 non-null    int64
#  12  min_max_NP_size                              547 non-null    float64
#  13  lg_Drug_dose                                 432 non-null    float64
#  14  kingdom                                      547 non-null    object
#  15  phylum                                       547 non-null    object
#  16  class                                        547 non-null    object
#  17  order                                        547 non-null    object
#  18  family                                       547 non-null    object
#  19  genus                                        547 non-null    object
#  20  species                                      547 non-null    object
#  21  gram                                         547 non-null    object
#  22  avg_Incub_period                             547 non-null    float64
#  23  growth_temp, C                               547 non-null    int64
#  24  biosafety_level                              547 non-null    int64
#  25  isolated_from                                547 non-null    object
#  26  Smiles                                       547 non-null    object
#  27  pKa                                          547 non-null    float64
#  28  LabuteASA                                    547 non-null    float64
#  29  NumHDonors                                   547 non-null    int64
#  30  NumHAcceptors                                547 non-null    int64
#  31  MolLogP                                      547 non-null    float64
#  32  MolWt                                        547 non-null    float64
#  33  Chi0                                         547 non-null    float64
#  34  RingCount                                    547 non-null    int64
#  35  TPSA                                         547 non-null    float64
#  36  NumAliphaticRings                            547 non-null    int64
#  37  NumAromaticRings                             547 non-null    int64
#  38  NumAromaticHeterocycles                      547 non-null    int64
#  39  MinPartialCharge                             547 non-null    float64
#  40  MaxPartialCharge                             547 non-null    float64
#  41  BertzCT                                      547 non-null    float64
# dtypes: float64(17), int64(9), object(16)
# memory usage: 179.6+ KB

# %% [markdown]
# # 6 | Добиваем NaNы

# %% [markdown]
# Для оставшихся (столбцы ```ZOI_drug, fold_increase.., lg_Drug_dose ```) применяем KNN, обучая его по всей таблице, за исключением систематики бактерий и класса препарата (слишком много лишних столбцов с учетом encoding).

# %% [markdown]
# Создадим дополнительную таблицу для обучения KNN

# %%
cols_to_drop = [
    'isolated_from', 'Smiles', 'species', 'genus', 'family', 'order', 'class',
    'phylum', 'kingdom', 'Drug_class_drug_bank'
]

df_dummy = deepcopy(df)
df_dummy = df_dummy.drop(columns=cols_to_drop)

df_dummy = pd.get_dummies(df_dummy, drop_first=True)

# %%
imp = KNNImputer()
df_dummy = imp.fit_transform(df_dummy)

df_dummy = pd.DataFrame(df_dummy, columns=imp.get_feature_names_out())

# %%
f'Total NaNs: {df_dummy.isna().sum().sum()}'
# Out:
# 'Total NaNs: 0'

# %% [markdown]
# Пока что будем работать с df_dummy

# %% [markdown]
# # 7 | Выбросы, корреляции и анализ

# %%
num_cols_final = deepcopy(num_cols)
num_cols_final.extend(descs_to_add)
num_cols_final.append('pKa')

# %%
sns.heatmap(df_dummy[num_cols_final].corr(), cmap='vlag')
# df_dummy[num_cols_final].corr()[df_dummy[num_cols_final].corr() > 0.7]
# Out:
# <Axes: >

# %% [markdown]
# --------------------------------! Внимание, медленная ячейка !-----------------------------

# %% [markdown]
# Сильно коррелируют столбцы дескрипторов, которые мы подгрузили. Перестарались, отменяем :)

# %%
last_drop = ['LabuteASA', 'MolWt', 'Chi0', 'NumHDonors', 'TPSA']
df_dummy.drop(columns=last_drop)
for col in last_drop:
    num_cols_final.remove(col)

# %%
sns.heatmap(df_dummy[num_cols_final].corr(), cmap='vlag')
# Out:
# <Axes: >

# %% [markdown]
# Красота! Остается посмотреть на распределения и pairplot

# %%
plot = sns.pairplot(df_dummy[num_cols_final], diag_kind='kde')
# plot.savefig('pairplot.png')

# %%
for col in num_cols_final:
    sns.violinplot(df_dummy[col], orient='h', width=0.7, palette='pastel')
    plt.title(col)
    plt.show()

# %% [markdown]
# Что-то странное с ```fold_increase``` и ```ZOI_drug```

# %%
for col, thresh in zip(['fold_increase_in_antibacterial_activity (%)', 'ZOI_drug'], [12, 80]):
    print(f'Column {col}, above {thresh}: {df_dummy[df_dummy[col] > thresh].shape[0]}')
    _med = df_dummy[col].median()
    df_dummy.loc[df_dummy[col] > thresh, col] = _med
    assert df_dummy[df_dummy[col] > thresh].shape[0] == 0
# Out:
# Column fold_increase_in_antibacterial_activity (%), above 12: 24
# Column ZOI_drug, above 80: 12

# %% [markdown]
# Очистка данных закончена! Переносим в ```df``` столбцы, в которых мы заполняли дырки KNN-ом:

# %%
cols_to_fill = ['ZOI_drug', 'fold_increase_in_antibacterial_activity (%)', 'lg_Drug_dose']
df.loc[:, cols_to_fill] = df_dummy[cols_to_fill]
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # 8 | Выбор ML-модели

# %% [markdown]
# ## Encoding
# Мы будем кодировать двумя способами и сравнивать результаты.

# %%
# Функция, кодирующая категориальные фичи в df с помощью 1) нумерации классов 2) one-hot. Возвращает оба варианта

def code_and_onehot(df: pd.DataFrame, cols_to_drop: list = []):
    ''' 
    Applies one-hod encoding and classes numeration for categorical features in df.
    
    Parameters
    ----------
    df: pandas Dataframe
        Columns are feature values
    cols_to_drop: list of strings
        Names of columns to drop before encoding
    
    Returns
    ----------
    (pd.DataFrame, pd.DataFrame)
        First one is the df with enumerated categorical features; second one is one-hot-encoded

    '''


    df_codes = deepcopy(df.drop(columns=cols_to_drop))
    df_onehot = deepcopy(df.drop(columns=cols_to_drop))

    for col in df.drop(columns=cols_to_drop):
        if df[col].dtype == object:
            df_codes[col] = pd.Categorical(df[col])
            df_codes[col] = df_codes[col].cat.codes

    df_onehot = pd.get_dummies(df_onehot, drop_first=True)
    
    return df_codes, df_onehot

# %%
cols_to_drop = ['Smiles']

df_codes, df_onehot = code_and_onehot(df, cols_to_drop)

df_nn = deepcopy(df_onehot)

# %% [markdown]
# ## Подбор регрессионной модели

# %% [markdown]
# Воспользуемся модулем LazyRegressor, который проверит кучу классических ML-регрессоров с "как правило, хорошими" параметрами и предоставит отчет об их скорах.

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

for encoded_df, name in zip([df_codes, df_onehot], ['----- df_codes -----\n', '\n\n----- df_onehot -----\n']):
    print(f'{name}')
    X_train, X_test, y_train, y_test = train_test_split(
        encoded_df.drop(columns=['ZOI_drug_NP']), encoded_df['ZOI_drug_NP'], random_state=RANDOM_STATE,
        test_size=0.25    
    )
    models, predictions = reg.fit(X_train, X_test, y_train, y_test)
    print(models)
# Out:
# ----- df_codes -----
# 100%|██████████| 42/42 [00:05<00:00,  7.92it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.80       0.86  3.67        0.43
# ExtraTreeRegressor                           0.76       0.83  4.00        0.06
# GradientBoostingRegressor                    0.74       0.82  4.16        0.20
# BaggingRegressor                             0.73       0.81  4.25        0.09
# RandomForestRegressor                        0.73       0.81  4.26        0.67
# XGBRegressor                                 0.72       0.80  4.32        1.25
# LGBMRegressor                                0.72       0.80  4.35        0.05
# HistGradientBoostingRegressor                0.71       0.80  4.40        0.26
# LassoLarsIC                                  0.66       0.76  4.78        0.02
# LassoLarsCV                                  0.66       0.76  4.79        0.07
# TransformedTargetRegressor                   0.66       0.76  4.79        0.01
# LinearRegression                             0.66       0.76  4.79        0.01
# RidgeCV                                      0.66       0.76  4.80        0.01
# LassoCV                                      0.66       0.76  4.83        0.19
# Ridge                                        0.66       0.76  4.83        0.01
# ElasticNetCV                                 0.65       0.75  4.85        0.15
# BayesianRidge                                0.65       0.75  4.87        0.02
# SGDRegressor                                 0.63       0.74  4.98        0.01
# DecisionTreeRegressor                        0.63       0.74  4.99        0.02
# MLPRegressor                                 0.61       0.72  5.17        0.29
# AdaBoostRegressor                            0.51       0.65  5.77        0.04
# PoissonRegressor                             0.48       0.63  5.95        0.02
# LarsCV                                       0.46       0.62  6.05        0.05
# OrthogonalMatchingPursuitCV                  0.45       0.61  6.09        0.02
# OrthogonalMatchingPursuit                    0.44       0.61  6.13        0.01
# LassoLars                                    0.42       0.59  6.26        0.01
# Lasso                                        0.42       0.59  6.26        0.01
# HuberRegressor                               0.42       0.59  6.29        0.04
# LinearSVR                                    0.39       0.57  6.43        0.02
# GammaRegressor                               0.36       0.55  6.59        0.13
# ElasticNet                                   0.34       0.53  6.68        0.01
# KNeighborsRegressor                          0.30       0.50  6.90        0.11
# TweedieRegressor                             0.30       0.50  6.90        0.01
# SVR                                          0.18       0.42  7.46        0.03
# PassiveAggressiveRegressor                   0.18       0.42  7.47        0.01
# NuSVR                                        0.13       0.39  7.65        0.02
# RANSACRegressor                              0.08       0.35  7.89        0.11
# DummyRegressor                              -0.43      -0.01  9.85        0.01
# QuantileRegressor                           -0.49      -0.05 10.03        0.76
# Lars                                        -2.40      -1.40 15.17        0.02
# KernelRidge                                 -3.03      -1.85 16.52        0.02
# GaussianProcessRegressor                    -3.41      -2.11 17.27        0.03
#
#
# ----- df_onehot -----
#
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:03<00:00, 12.97it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# KernelRidge                                  7.36      -2.18 17.45        0.01
# PassiveAggressiveRegressor                   3.55      -0.27 11.05        0.01
# GaussianProcessRegressor                     3.46      -0.23 10.87        0.02
# QuantileRegressor                            3.10      -0.05 10.03        0.74
# DummyRegressor                               3.02      -0.01  9.85        0.01
# RANSACRegressor                              2.76       0.12  9.17        0.09
# LinearSVR                                    2.57       0.21  8.68        0.02
# HuberRegressor                               2.54       0.23  8.59        0.03
# PoissonRegressor                             2.44       0.28  8.31        0.02
# GammaRegressor                               2.35       0.32  8.04        0.01
# TweedieRegressor                             2.28       0.36  7.82        0.01
# NuSVR                                        2.21       0.40  7.61        0.02
# ElasticNet                                   2.20       0.40  7.58        0.01
# KNeighborsRegressor                          2.19       0.40  7.56        0.01
# OrthogonalMatchingPursuit                    2.18       0.41  7.52        0.01
# OrthogonalMatchingPursuitCV                  2.12       0.44  7.33        0.01
# LassoLars                                    2.12       0.44  7.31        0.01
# Lasso                                        2.12       0.44  7.31        0.01
# SVR                                          2.11       0.45  7.29        0.03
# Lars                                         2.10       0.45  7.26        0.02
# SGDRegressor                                 2.06       0.47  7.14        0.01
# LassoCV                                      2.06       0.47  7.13        0.14
# LassoLarsCV                                  2.06       0.47  7.13        0.03
# LarsCV                                       2.06       0.47  7.13        0.03
# LassoLarsIC                                  2.06       0.47  7.12        0.01
# ElasticNetCV                                 2.05       0.47  7.10        0.10
# RidgeCV                                      2.05       0.48  7.08        0.01
# BayesianRidge                                2.05       0.48  7.08        0.01
# Ridge                                        2.04       0.48  7.08        0.01
# LinearRegression                             2.04       0.48  7.08        0.01
# TransformedTargetRegressor                   2.04       0.48  7.08        0.01
# MLPRegressor                                 2.00       0.50  6.92        0.26
# AdaBoostRegressor                            1.80       0.60  6.20        0.04
# LGBMRegressor                                1.60       0.70  5.35        0.06
# HistGradientBoostingRegressor                1.59       0.71  5.30        0.24
# DecisionTreeRegressor                        1.52       0.74  4.99        0.01
# BaggingRegressor                             1.51       0.75  4.92        0.07
# RandomForestRegressor                        1.50       0.75  4.89        0.50
# GradientBoostingRegressor                    1.48       0.76  4.82        0.15
# XGBRegressor                                 1.47       0.76  4.77        0.07
# ExtraTreeRegressor                           1.36       0.82  4.17        0.01
# ExtraTreesRegressor                          1.36       0.82  4.17        0.32

# %% [markdown]
# Пока что модели ExtraTreeRegressor (одно решающее дерево!) и ExtraTreesRegressor (ансамбль деревьев) лидируют по скору. Между one-hot-encoding и нумерацией классов разница несущественная, и R^2=0.86

# %% [markdown]
# Проверим еще и CatBoost (в LazyPredict его нет). Заодно выясним, какие фичи являются ключевыми в моделях (25 наиболее важных признаков), оставим только их и проверим, насколько подрастёт скор.

# %%
def get_scores_by_models(
        models: list, df: pd.DataFrame, random_state=RANDOM_STATE, test_size=0.25, 
        get_features=True, plot_features=False
):
    
    ''' 
    Trains each model in models list, gets their scores and feature importances. Returns 25 best features and prints the scores.

    Parameters
    -----------
    models: list of sklearn.Model objects
        Models to train and test.
    df: pd.DataFrame
        Training data (target column is hardcoded).
    get_features: bool
        Whether to return 25 most important features.
    plot_features: bool
        Whether to plot feature importance histogram
    '''

    X_train, X_test, y_train, y_test = train_test_split(
        df.drop(columns=['ZOI_drug_NP']), df['ZOI_drug_NP'], random_state=RANDOM_STATE,
        test_size=test_size    
    )
    
    list_best = []

    for model in models:
        pipe = Pipeline([('scaler', StandardScaler()), ('model', model)])
        pipe.fit(X_train, y_train)
        pred = pipe.predict(X_test)

        print(f'--- {pipe["model"].__class__.__name__} ---')
        print(f'R2 score: {r2_score(y_test, pred)}')
        print(f'RMSE score: {mean_squared_error(y_test, pred) ** 0.5}')

        if get_features or plot_features:

            feature_importance = pipe["model"].feature_importances_
            sorted_idx = np.argsort(feature_importance)

            if plot_features:
                plt.figure(figsize=(8, 8))
                plt.barh(range(len(sorted_idx[-25:])), feature_importance[sorted_idx[-25:]], align='center')
                plt.yticks(range(len(sorted_idx[-25:])), np.array(X_test.columns)[sorted_idx[-25:]])
                plt.title(f'Feature Importance for {pipe["model"].__class__.__name__}');
            
            best_features = np.array(X_test.columns)[sorted_idx[-25:]]
            list_best.extend(best_features)
        
    return list_best

# %%
ex_tree = ExtraTreesRegressor(random_state=RANDOM_STATE, n_jobs=-1)
cat = CatBoostRegressor(random_state=RANDOM_STATE, verbose=0)

models = [ex_tree, cat]
features = {}
final_datas = []

df_codes, df_onehot = code_and_onehot(df, cols_to_drop)

for encoded_df, name in zip([df_codes, df_onehot], ['----- df_codes -----\n', '\n\n----- df_onehot -----\n']):
    
    print(f'{name}')
    
    list_best = get_scores_by_models(models, encoded_df)
    
    list_best = list(set(list_best))
    print(f'Amount of important features for two model: {len(list_best)}')
    
    print(f'\nScores after dropping non-important features:')
    
    list_best.append('ZOI_drug_NP')
    encoded_df = encoded_df[list_best]
    final_datas.append(encoded_df)
    
    get_scores_by_models(models, encoded_df)

df_codes_final, df_onehot_final = final_datas
# Out:
# ----- df_codes -----
# --- ExtraTreesRegressor ---
# R2 score: 0.8594592044951634
# RMSE score: 3.6705543786658037
# --- CatBoostRegressor ---
# R2 score: 0.8337642938629183
# RMSE score: 3.9920191412010992
# Amount of important features for two model: 30
#
# Scores after dropping non-important features:
# --- ExtraTreesRegressor ---
# R2 score: 0.8676952977409325
# RMSE score: 3.5613782218464207
# --- CatBoostRegressor ---
# R2 score: 0.8425239993514546
# RMSE score: 3.8854170987392167
#
#
# ----- df_onehot -----
#
# --- ExtraTreesRegressor ---
# R2 score: 0.8697611048229199
# RMSE score: 3.5334651349198776
# --- CatBoostRegressor ---
# R2 score: 0.8320837658017698
# RMSE score: 4.0121466770569985
# Amount of important features for two model: 39
#
# Scores after dropping non-important features:
# --- ExtraTreesRegressor ---
# R2 score: 0.871596870964929
# RMSE score: 3.508473998443693
# --- CatBoostRegressor ---
# R2 score: 0.8224337718951138
# RMSE score: 4.12582348328297

# %% [markdown]
# Если оставлять только самые важные признаки, ExtraTreesRegressor всё равно выигрывает CatBoost, и R^2 вырастает до 0.87.

# %% [markdown]
# ## GridSearch для лучших моделей
#
# Ищем лучшие наборы параметров для CatBoost и ExtraTreesRegressor

# %%
def make_gridsearchCV_by_models(
        models_params: list, 
        df: pd.DataFrame, 
        test_size=0.25, 
        cv=4, 
        random_state=RANDOM_STATE
):
    ''' 
    Trains each model in models list, gets their scores and feature importances. Returns 25 best features and prints the scores.

    Parameters
    -----------
    models_params: list
        List of lists with models and parameters.
    df: pd.DataFrame
        Training data (target column is hardcoded).
    test_size: float default=0.25
        Size of test to train/test split.
    cv: int default=4
        Specify the number of folds
    random_state: int
    '''

    X_train, X_test, y_train, y_test = train_test_split(
        df.drop(columns=['ZOI_drug_NP']), df['ZOI_drug_NP'], random_state=random_state,
        test_size=test_size    
    )
    
    models = []

    for model in models_params:
        
        pipe = Pipeline([('scaler', StandardScaler()), ('model', model[0])])
        grid = GridSearchCV(pipe, model[1], scoring='r2', n_jobs=-1, cv=cv)
        grid.fit(X_train, y_train)

        print(f'--- Model: {pipe["model"].__class__.__name__} ---\n')
        print(f'Best params: {grid.best_params_}')
        print(f'Best CV R2 score: {grid.best_score_}')
        print(f'R2 score on unseen data: {r2_score(y_test, grid.best_estimator_.predict(X_test))}')
        
        models.append(grid.best_estimator_['model'])
    
    return models

# %% [markdown]
# ---- следующая ячейка грзуится ~6 минут на AMD Ryzen 5 4600H 3.0 GHz --- \
# (ее можно пропустить и загрузить модели из файла ```best_models.pkl``` в следующей ячейке)

# %%
cat = CatBoostRegressor(random_state=RANDOM_STATE, verbose=0)
cat_params = {
    'model__depth': [1, 2, 3],
    'model__iterations': [500, 1000, 3000, 6000],
    'model__learning_rate': [0.05, 0.1, 0.3, 0.5], 
    'model__l2_leaf_reg': [0.5, 1, 3],
}


ex_tree = ExtraTreesRegressor(random_state=RANDOM_STATE, n_jobs=-1)
tree_params = {
    'model__max_depth': [10, 50, 100],
    'model__n_estimators': [50, 75, 100, 150],
    'model__criterion': ['squared_error', 'absolute_error', 'friedman_mse'], 
    'model__min_samples_split': [2, 3, 4],
}

models_params = [
    [cat, cat_params],
    [ex_tree, tree_params]
]

best_models ={}

for encoded_df, name in zip(
    [df_onehot_final, df_codes_final], 
    ['onehot_final', 'codes_final']
):
    print(name)
    models = make_gridsearchCV_by_models(models_params, encoded_df, cv=4)
    best_models.update({name: models})
# Out:
# onehot_final
#
# --- Model: CatBoostRegressor ---
#
# Best params: {'model__depth': 2, 'model__iterations': 3000, 'model__l2_leaf_reg': 1, 'model__learning_rate': 0.05}
# Best CV R2 score: 0.8250520346855933
# R2 score on unseen data: 0.8356323962364899
#
# --- Model: ExtraTreesRegressor ---
#
# Best params: {'model__criterion': 'absolute_error', 'model__max_depth': 50, 'model__min_samples_split': 3, 'model__n_estimators': 150}
# Best CV R2 score: 0.8234177116940263
# R2 score on unseen data: 0.8453432058094241
# codes_final
#
# --- Model: CatBoostRegressor ---
#
# Best params: {'model__depth': 2, 'model__iterations': 6000, 'model__l2_leaf_reg': 0.5, 'model__learning_rate': 0.1}
# Best CV R2 score: 0.8291903033799587
# R2 score on unseen data: 0.8248234994069509
#
# --- Model: ExtraTreesRegressor ---
#
# Best params: {'model__criterion': 'absolute_error', 'model__max_depth': 50, 'model__min_samples_split': 3, 'model__n_estimators': 100}
# Best CV R2 score: 0.8368342853384252
# R2 score on unseen data: 0.853501047244057

# %%
best_models
# Out:
# {'onehot_final': [<catboost.core.CatBoostRegressor at 0x20584859990>,
#   ExtraTreesRegressor(criterion='absolute_error', max_depth=50,
#                       min_samples_split=3, n_estimators=150, n_jobs=-1,
#                       random_state=42)],
#  'codes_final': [<catboost.core.CatBoostRegressor at 0x20580e84400>,
#   ExtraTreesRegressor(criterion='absolute_error', max_depth=50,
#                       min_samples_split=3, n_jobs=-1, random_state=42)]}

# %% [markdown]
# Смотрим на лучшие наборы параметров. Первый элемент списка - для кодирования one-hot, второй - для кат. фичей номерами.

# %%
# pickle.dump(best_models, open('best_models.pkl', 'wb'))
best_models = pickle.load(open('best_models.pkl', 'rb'))
best_models
# Out:
# {'onehot_final': [<catboost.core.CatBoostRegressor at 0x205f3ec7970>,
#   ExtraTreesRegressor(criterion='absolute_error', max_depth=50,
#                       min_samples_split=3, n_estimators=150, n_jobs=-1,
#                       random_state=42)],
#  'codes_final': [<catboost.core.CatBoostRegressor at 0x20580f26a40>,
#   ExtraTreesRegressor(criterion='absolute_error', max_depth=50,
#                       min_samples_split=3, n_jobs=-1, random_state=42)]}

# %% [markdown]
# Попробуем применить голосование (VotingRegressor) для CatBoost и ExtraTreesRegressor и посмотрим его качество на кросс-валидации

# %%
best_models['onehot_final']
# Out:
# [<catboost.core.CatBoostRegressor at 0x205f3ec7970>,
#  ExtraTreesRegressor(criterion='absolute_error', max_depth=50,
#                      min_samples_split=3, n_estimators=150, n_jobs=-1,
#                      random_state=42)]

# %%
for group_models, encoded_df, name in zip(
    best_models.values(), 
    [df_onehot_final, df_codes_final], 
    ['---- df_onehot_final ----\n', '\n\n---- df_codes_final ----\n']
):
    
    print(name)
    X, y = shuffle(
        encoded_df.drop(columns=['ZOI_drug_NP']), encoded_df['ZOI_drug_NP'], 
        random_state=RANDOM_STATE
    )

    vot = VotingRegressor([('cat', group_models[0]), ('ex_tree', group_models[1])], n_jobs=-1)
    pipe = Pipeline([('scaler', StandardScaler()), ('model',vot)])
    score = cross_val_score(
        pipe, X, y,
        cv=4, scoring='r2'
    )
    
    print(f'R2 score: {score.mean()} with a standard deviation {score.std()}')
    print(f'R2 score max: {score.max()}')
# Out:
# ---- df_onehot_final ----
#
# R2 score: 0.8288618958469438 with a standard deviation 0.01883890225433659
# R2 score max: 0.8515080971584705
#
#
# ---- df_codes_final ----
#
# R2 score: 0.8400109296199705 with a standard deviation 0.025673988730676018
# R2 score max: 0.8664246249443022

# %% [markdown]
# Score получается почти одинаковый и даже немного меньше, чем для моделей отдельно \
# Отобразим кривые обучения всего ансамбля и выбранные фичи для каждой модели внутри на датасете df_codes_final

# %%
# Визуализация работы VotingRegressor на лучших моделях с помощью LearningCurveDisplay
X, y = df_codes_final.drop(columns=['ZOI_drug_NP']), df_codes_final['ZOI_drug_NP']
X, y = shuffle(X, y, random_state=RANDOM_STATE)

fig, ax = plt.subplots(figsize=(10, 6))
pipe = Pipeline([('scaler', StandardScaler()), ('model', vot)])
LearningCurveDisplay.from_estimator(
    pipe, X=X, y=y,
    ax=ax, n_jobs=-1, 
)

handles, label = ax.get_legend_handles_labels()
ax.legend(handles[:2], ["Training Score", "Test Score"])
ax.set_title(f"Learning Curve for {pipe['model'].__class__.__name__}");

# %%
fig, ax = plt.subplots(2, 1, figsize=(8, 20))

for i, model in enumerate(pipe['model'].estimators):
    model = model[1]
    feature_importance = model.feature_importances_
    sorted_idx = np.argsort(feature_importance)
    ax[i].barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
    ax[i].set_yticks(range(len(sorted_idx)), minor=False)
    ax[i].set_yticklabels(np.array(X.columns)[sorted_idx])
    ax[i].set_title(f'Feature Importance for {model.__class__.__name__}')

# %% [markdown]
# ## Подготовка моделей

# %% [markdown]
# Подготовим модель, обученную на датасете с categorical codes encoding для дальнейших предсказаний

# %%
best_models = pickle.load(open('best_models.pkl', 'rb'))['codes_final']

vot = VotingRegressor([('cat', best_models[0]), ('ex_tree', best_models[1])], n_jobs=-1)
best_models.append(vot)

X, y = shuffle(
    df_codes_final.drop(columns=['ZOI_drug_NP']), df_codes_final['ZOI_drug_NP'], 
    random_state=RANDOM_STATE
)

models_to_pack = {}

for model in best_models:
    pipe = Pipeline([('scaler', StandardScaler()), ('model', model)])
    pipe.fit(X, y)
    model = pipe['model']
    models_to_pack.update(
        {model.__class__.__name__: pipe}
    )

# выкидываем ZOI_drug_NP т.к. это таргет
models_to_pack.update({'features': df_codes_final.drop(columns=['ZOI_drug_NP']).columns})
pickle.dump(models_to_pack, open('fitted_models.pkl', 'wb'))

# %%
def get_prediction(df: pd.DataFrame, choosen_model='ExtraTreesRegressor', show_features=False): # or CatBoostRegressor or VotingRegressor
    '''
    Perform data and make prediction

    Parameters
    -----------
    df: DataFrame
        Dataset to prediction must contains same features
        (use show_features)
    choosen_model: str default="ExtraTreesRegressor"
        Use model from fitted_models.pkl, available models:
        ExtraTreesRegressor, CatBoostRegressor, VotingRegressor 
    show_features: bool default=False
        Print necessary features
    
    Returns
    -------
    predicted_values
    '''

    fitted_models = pickle.load(open('fitted_models.pkl', 'rb'))
    features = fitted_models['features']

    if show_features:
        print(features)
        return
    
    model = fitted_models[choosen_model]
    
    df_codes = deepcopy(df[features])

    for col in df[features]:
        if df[col].dtype == object:
            df_codes[col] = pd.Categorical(df[col])
            df_codes[col] = df_codes[col].cat.codes
            
    return model.predict(df_codes)

# %%
X, y = shuffle(df.drop(columns=['ZOI_drug_NP']), df['ZOI_drug_NP'])
r2_score(y, get_prediction(X))
# Out:
# 0.9670997382604543

# %% [markdown]
# # 9 | Обучаем нейросеть
# Для этой задачи мы построим полносвязную нейронную сеть на PyTorch. Особо перебирать архитектуру не будем, пара заметок - не нужно делать очень уж глубокую сеть, поскольку датасет маленький: если будет адекватный скор - уже хорошо.

# %% [markdown]
# ## Загрузка и предобработка данных

# %%
df = df_nn

X = torch.tensor(df.drop(columns=['ZOI_drug_NP']).astype('float32').to_numpy())
y = torch.tensor(df['ZOI_drug_NP'].astype('float32').to_numpy().reshape(-1, 1))

# %% [markdown]
# Данные нужно отмасштабировать, чтобы градиенты не взрывались

# %%
scaler = MinMaxScaler()
scaler.fit_transform(X, y)
# Out:
# array([[2.22222222e-01, 5.96745060e-02, 5.00000000e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [2.22222222e-01, 5.96745060e-02, 5.00000000e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [2.22222222e-01, 4.21338158e-01, 5.00000000e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.22222222e-01, 5.96745060e-02, 4.68749990e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.22222222e-01, 4.21338158e-01, 4.68749990e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.22222222e-01, 1.00000000e+00, 3.90625000e-02, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# Делим на тест и трейн

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=0.07)
print(f'Train: {X.shape[0]}, test: {X_test.shape[0]}')
print(f'Features: {X.shape[1]}')
# Out:
# Train: 508, test: 39
# Features: 204

# %% [markdown]
# ## Модель

# %% [markdown]
# Попробуем небольшую модель с одним скрытым слоем, в котором нейронов будет втрое меньше, чем на входе. После входного и скрытого слоев будет функция активации: по дефолту поставим ReLU(x) = max(0, x), а потом подберем лучшую.

# %% [markdown]
# Дропаут - это защита от переобучения. При применении дропаута ```0 <= w * 100% <= 100%``` нейронов деактивируется, ```w``` - аргумент ```nn.Dropout()```. Сначала исследуем модель без него, лучшие параметры применим для модели с дропаутом.

# %%
class DenseNN(nn.Module):
    def __init__(self, in_features: int, activation=F.relu, do_dropout=False):
        super(DenseNN, self).__init__()
        self.activation = activation
        self.fc1 = nn.Linear(in_features, in_features)
        self.fc2 = nn.Linear(in_features, in_features // 3)
        self.fc3 = nn.Linear(in_features // 3, 1)
        self.do_dropout = do_dropout
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        x = self.activation(self.fc1(x))
        
        if self.do_dropout:
            x = self.dropout(x)

        x = self.activation(self.fc2(x))
        
        if self.do_dropout:
            x = self.dropout(x)        
        
        x = self.fc3(x)
        return x

# %% [markdown]
# ## Обучаем модель

# %% [markdown]
# Лосс - MSE как стандарт для регрессии, оптимизация Adam либо SGD

# %%
def test_model(loss_fn_name=nn.MSELoss, 
               optimizer_lr=torch.optim.Adam,
               n_epochs=100,
               batch_size=6,
               activation_name=F.relu,
               do_dropout=False,
               verbose=True):
    ''' 
    Performs DenseNN model training, including r2-scoring on test data every epoch 
    Parameters are obvious
    
    Returns
    -------
    (model, history_loss, history_r2): tuple of DenseNN(nn.Module), list, list
        Trained model, loss and r2 scores for each epoch 
    '''

    model = DenseNN(X.shape[1], activation=activation_name, do_dropout=do_dropout)
    loss_fn = loss_fn_name()
    optimizer = optimizer_lr[0](model.parameters(), lr=optimizer_lr[1])

    history_loss = []
    history_r2 = []

    for n_epoch in range(n_epochs):
        for i in range(0, len(X), batch_size):
            Xbatch = X[i:i+batch_size]
            
            y_pred = model(Xbatch)
        
            ybatch = y[i:i+batch_size]

            loss = loss_fn(y_pred, ybatch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        history_loss.append(loss.item())
        history_r2.append(r2_score(y_test.detach().numpy(), model(X_test).detach().numpy()))
        
        if verbose:
            print(f'Finished epoch {n_epoch + 1}/{n_epochs}, latest loss {history_loss[-1]:.3f}, R^2 on test {history_r2[-1]:.3f}')

    return model, history_loss, history_r2

# %%
model, history_loss, history_r2 = test_model()

sns.scatterplot(history_loss)
plt.title('Loss')
plt.show()
sns.scatterplot(history_r2)
plt.title(f'R2, last = {round(r2_score(y_test.detach().numpy(), model(X_test).detach().floor().numpy()), 3)}, best = {max(history_r2)}')
plt.ylim(0, 1)
plt.show()
# Out:
# Finished epoch 1/100, latest loss 71.142, R^2 on test -0.621
# Finished epoch 2/100, latest loss 65.745, R^2 on test -0.451
# Finished epoch 3/100, latest loss 77.487, R^2 on test -0.158
# Finished epoch 4/100, latest loss 67.344, R^2 on test -0.109
# Finished epoch 5/100, latest loss 50.504, R^2 on test -0.103
# Finished epoch 6/100, latest loss 39.450, R^2 on test -0.018
# Finished epoch 7/100, latest loss 27.746, R^2 on test 0.013
# Finished epoch 8/100, latest loss 17.645, R^2 on test 0.038
# Finished epoch 9/100, latest loss 11.176, R^2 on test 0.018
# Finished epoch 10/100, latest loss 8.545, R^2 on test 0.029
# Finished epoch 11/100, latest loss 7.376, R^2 on test 0.039
# Finished epoch 12/100, latest loss 7.085, R^2 on test 0.080
# Finished epoch 13/100, latest loss 7.041, R^2 on test 0.121
# Finished epoch 14/100, latest loss 7.694, R^2 on test 0.109
# Finished epoch 15/100, latest loss 6.838, R^2 on test 0.167
# Finished epoch 16/100, latest loss 7.949, R^2 on test 0.166
# Finished epoch 17/100, latest loss 8.623, R^2 on test 0.152
# Finished epoch 18/100, latest loss 7.924, R^2 on test 0.246
# Finished epoch 19/100, latest loss 9.384, R^2 on test 0.191
# Finished epoch 20/100, latest loss 8.634, R^2 on test 0.276
# Finished epoch 21/100, latest loss 8.601, R^2 on test 0.297
# Finished epoch 22/100, latest loss 8.784, R^2 on test 0.324
# Finished epoch 23/100, latest loss 8.809, R^2 on test 0.345
# Finished epoch 24/100, latest loss 9.425, R^2 on test 0.352
# Finished epoch 25/100, latest loss 9.796, R^2 on test 0.345
# Finished epoch 26/100, latest loss 9.880, R^2 on test 0.378
# Finished epoch 27/100, latest loss 9.178, R^2 on test 0.423
# Finished epoch 28/100, latest loss 9.735, R^2 on test 0.412
# Finished epoch 29/100, latest loss 9.331, R^2 on test 0.454
# Finished epoch 30/100, latest loss 9.082, R^2 on test 0.465
# Finished epoch 31/100, latest loss 9.307, R^2 on test 0.478
# Finished epoch 32/100, latest loss 9.659, R^2 on test 0.484
# Finished epoch 33/100, latest loss 9.130, R^2 on test 0.515
# Finished epoch 34/100, latest loss 8.744, R^2 on test 0.527
# Finished epoch 35/100, latest loss 8.727, R^2 on test 0.550
# Finished epoch 36/100, latest loss 8.047, R^2 on test 0.602
# Finished epoch 37/100, latest loss 9.513, R^2 on test 0.721
# Finished epoch 38/100, latest loss 8.041, R^2 on test 0.650
# Finished epoch 39/100, latest loss 8.377, R^2 on test 0.616
# Finished epoch 40/100, latest loss 8.576, R^2 on test 0.611
# Finished epoch 41/100, latest loss 7.878, R^2 on test 0.637
# Finished epoch 42/100, latest loss 7.611, R^2 on test 0.630
# Finished epoch 43/100, latest loss 7.925, R^2 on test 0.698
# Finished epoch 44/100, latest loss 7.983, R^2 on test 0.637
# Finished epoch 45/100, latest loss 7.976, R^2 on test 0.665
# Finished epoch 46/100, latest loss 7.920, R^2 on test 0.628
# Finished epoch 47/100, latest loss 7.620, R^2 on test 0.668
# Finished epoch 48/100, latest loss 7.109, R^2 on test 0.674
# Finished epoch 49/100, latest loss 7.783, R^2 on test 0.710
# Finished epoch 50/100, latest loss 7.473, R^2 on test 0.704
# Finished epoch 51/100, latest loss 7.793, R^2 on test 0.760
# Finished epoch 52/100, latest loss 8.387, R^2 on test 0.772
# Finished epoch 53/100, latest loss 7.056, R^2 on test 0.763
# Finished epoch 54/100, latest loss 8.454, R^2 on test 0.797
# Finished epoch 55/100, latest loss 10.100, R^2 on test 0.807
# Finished epoch 56/100, latest loss 7.372, R^2 on test 0.780
# Finished epoch 57/100, latest loss 10.131, R^2 on test 0.818
# Finished epoch 58/100, latest loss 8.964, R^2 on test 0.813
# Finished epoch 59/100, latest loss 8.807, R^2 on test 0.814
# Finished epoch 60/100, latest loss 7.601, R^2 on test 0.798
# Finished epoch 61/100, latest loss 7.220, R^2 on test 0.797
# Finished epoch 62/100, latest loss 7.309, R^2 on test 0.805
# Finished epoch 63/100, latest loss 7.906, R^2 on test 0.816
# Finished epoch 64/100, latest loss 6.805, R^2 on test 0.816
# Finished epoch 65/100, latest loss 9.227, R^2 on test 0.837
# Finished epoch 66/100, latest loss 7.304, R^2 on test 0.829
# Finished epoch 67/100, latest loss 8.707, R^2 on test 0.840
# Finished epoch 68/100, latest loss 8.553, R^2 on test 0.844
# Finished epoch 69/100, latest loss 8.890, R^2 on test 0.846
# Finished epoch 70/100, latest loss 8.178, R^2 on test 0.844
# Finished epoch 71/100, latest loss 11.095, R^2 on test 0.850
# Finished epoch 72/100, latest loss 10.056, R^2 on test 0.850
# Finished epoch 73/100, latest loss 8.332, R^2 on test 0.852
# Finished epoch 74/100, latest loss 9.087, R^2 on test 0.853
# Finished epoch 75/100, latest loss 11.157, R^2 on test 0.852
# Finished epoch 76/100, latest loss 14.230, R^2 on test 0.842
# Finished epoch 77/100, latest loss 9.142, R^2 on test 0.852
# Finished epoch 78/100, latest loss 11.605, R^2 on test 0.850
# Finished epoch 79/100, latest loss 11.578, R^2 on test 0.848
# Finished epoch 80/100, latest loss 16.072, R^2 on test 0.831
# Finished epoch 81/100, latest loss 15.173, R^2 on test 0.828
# Finished epoch 82/100, latest loss 16.747, R^2 on test 0.824
# Finished epoch 83/100, latest loss 15.743, R^2 on test 0.821
# Finished epoch 84/100, latest loss 13.092, R^2 on test 0.834
# Finished epoch 85/100, latest loss 13.237, R^2 on test 0.835
# Finished epoch 86/100, latest loss 12.138, R^2 on test 0.840
# Finished epoch 87/100, latest loss 11.317, R^2 on test 0.842
# Finished epoch 88/100, latest loss 11.651, R^2 on test 0.840
# Finished epoch 89/100, latest loss 9.472, R^2 on test 0.846
# Finished epoch 90/100, latest loss 7.448, R^2 on test 0.851
# Finished epoch 91/100, latest loss 6.864, R^2 on test 0.855
# Finished epoch 92/100, latest loss 5.654, R^2 on test 0.858
# Finished epoch 93/100, latest loss 4.245, R^2 on test 0.858
# Finished epoch 94/100, latest loss 4.472, R^2 on test 0.852
# Finished epoch 95/100, latest loss 4.347, R^2 on test 0.852
# Finished epoch 96/100, latest loss 4.616, R^2 on test 0.840
# Finished epoch 97/100, latest loss 4.002, R^2 on test 0.849
# Finished epoch 98/100, latest loss 4.669, R^2 on test 0.841
# Finished epoch 99/100, latest loss 5.101, R^2 on test 0.828
# Finished epoch 100/100, latest loss 3.877, R^2 on test 0.849

# %% [markdown]
# ## Подбор лучших параметров
# Сделаем простейший гридсёрч с помощью итератора

# %%
def get_params(param_list_1, param_list_2=None, param_list_3=None, param_list_4=None, param_list_5=None):
    ''' 
    Parameters:
    -----------
    param_list_i: list
        Parameters to choose from. If unset or None, not used in grid

    Yields:
    -----------
    (param_1, param_2, ...): tuple, len = 5

    '''
    
    for param_1 in param_list_1:
        if param_list_2:
            for param_2 in param_list_2:
                if param_list_3:
                    for param_3 in param_list_3:
                        if param_list_4:
                            for param_4 in param_list_4:
                                if param_list_5:
                                    for param_5 in param_list_5:
                                        yield param_1, param_2, param_3, param_4, param_5
                                else:
                                    yield param_1, param_2, param_3, param_4, None
                        else:
                            yield param_1, param_2, param_3, None, None
                else:
                    yield param_1, param_2, None, None, None
        else:
            yield param_1, None, None, None, None

# %%
optimizers = [(torch.optim.Adam, 2.5e-4), (torch.optim.SGD, 5e-5)]
activations = [F.relu, F.elu, F.leaky_relu, torch.sigmoid]
dropout_modes = [False, True]
ns_epochs = [50, 75, 100, 200, 500]

for optimizer, activation, dropout_mode, n_epochs, _ in get_params(optimizers, activations, dropout_modes, ns_epochs):
    model, history_loss, history_r2 = test_model(optimizer_lr=optimizer, 
                                                 n_epochs=n_epochs, 
                                                 activation_name=activation, 
                                                 do_dropout=dropout_mode,
                                                 verbose=False)
    print('-------------------------')
    print(f'''Params:
                optimizer ....... {optimizer[0].__name__},
                activation ...... {activation.__name__},
                do dropout ...... {dropout_mode},
                epochs .......... {n_epochs}
          ''')
    print(f'Max R2: {max(history_r2)}, last R2: {history_r2[-1]}')
# Out:
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... False,
#                 epochs .......... 50
#
# Max R2: 0.001986280273728269, last R2: -0.060634043022871786
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... False,
#                 epochs .......... 75
#
# Max R2: 0.12138716504200564, last R2: 0.06147922083721624
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... False,
#                 epochs .......... 100
#
# Max R2: 0.17262391871499116, last R2: 0.1546509736989342
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... False,
#                 epochs .......... 200
#
# Max R2: 0.3795389933019183, last R2: 0.36413981987358535
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... True,
#                 epochs .......... 50
#
# Max R2: 0.06532554034876226, last R2: -0.09684151397739904
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... True,
#                 epochs .......... 75
#
# Max R2: 0.09110642843181771, last R2: -0.40039790813499887
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... True,
#                 epochs .......... 100
#
# Max R2: 0.06548403619022714, last R2: -0.19135539261059842
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... relu,
#                 do dropout ...... True,
#                 epochs .......... 200
#
# Max R2: 0.27137318933625076, last R2: 0.06971149774256002
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... elu,
#                 do dropout ...... False,
#                 epochs .......... 50
#
# Max R2: 0.129227535453316, last R2: 0.05629952204025135
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... elu,
#                 do dropout ...... False,
#                 epochs .......... 75
#
# Max R2: 0.12615380118715736, last R2: 0.06599215053844809
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... elu,
#                 do dropout ...... False,
#                 epochs .......... 100
#
# Max R2: 0.2355716476006421, last R2: 0.21402307011010124
# -------------------------
# Params:
#                 optimizer ....... SGD,
#                 activation ...... elu,
#                 do dropout ...... False,
#                 epochs .......... 200
#
# Max R2: 0.37879911808455335, last R2: 0.37259522953944635
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[188], line 7
#       4 ns_epochs = [50, 75, 100, 200]
#       6 for optimizer, activation, dropout_mode, n_epochs, _ in get_params(optimizers, activations, dropout_modes, ns_epochs):
# ----> 7     model, history_loss, history_r2 = test_model(optimizer_lr=optimizer,
#       8                                                  n_epochs=n_epochs,
#       9                                                  activation_name=activation,
#      10                                                  do_dropout=dropout_mode,
#      11                                                  verbose=False)
#      12     print('-------------------------')
#      13     print(f'''Params:
#      14                 optimizer ....... {optimizer[0].__name__},
#      15                 activation ...... {activation.__name__},
#      16                 do dropout ...... {dropout_mode},
#      17                 epochs .......... {n_epochs}
#      18           ''')
#
# Cell In[186], line 35, in test_model(loss_fn_name, optimizer_lr, n_epochs, batch_size, activation_name, do_dropout, verbose)
#      33     loss = loss_fn(y_pred, ybatch)
#      34     optimizer.zero_grad()
# ---> 35     loss.backward()
#      36     optimizer.step()
#      38 history_loss.append(loss.item())
#
# File ~/miniconda3/envs/ml/lib/python3.8/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/miniconda3/envs/ml/lib/python3.8/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# Результаты обучения см. в nn_dump.txt. SGD очень медленно обучался, а при повышении lr градиенты взрывались.

# %% [markdown]
# Лучшие параметры:
# Adam, elu, с дропаутом, чуть меньше чем 200 эпох. ```R^2 = 0.9125``` !!!!!

# %%
model, history_loss, history_r2 = test_model(optimizer_lr=(torch.optim.Adam, 2.5e-4), 
                                                 n_epochs=200, 
                                                 activation_name=F.elu, 
                                                 do_dropout=True,
                                                 verbose=True)

sns.scatterplot(history_loss)
plt.title('Loss')
plt.show()
sns.scatterplot(history_r2)
plt.title(f'R2, last = {round(r2_score(y_test.detach().numpy(), model(X_test).detach().floor().numpy()), 3)}, best = {max(history_r2)}')
plt.ylim(0, 1)
plt.show()
# Out:
# Finished epoch 1/200, latest loss 151.786, R^2 on test 0.139
# Finished epoch 2/200, latest loss 628.729, R^2 on test -0.068
# Finished epoch 3/200, latest loss 98.567, R^2 on test -0.059
# Finished epoch 4/200, latest loss 146.159, R^2 on test -0.470
# Finished epoch 5/200, latest loss 41.796, R^2 on test -0.253
# Finished epoch 6/200, latest loss 174.522, R^2 on test -0.150
# Finished epoch 7/200, latest loss 74.268, R^2 on test 0.010
# Finished epoch 8/200, latest loss 58.580, R^2 on test -0.201
# Finished epoch 9/200, latest loss 63.554, R^2 on test 0.061
# Finished epoch 10/200, latest loss 60.124, R^2 on test 0.121
# Finished epoch 11/200, latest loss 46.973, R^2 on test 0.259
# Finished epoch 12/200, latest loss 86.689, R^2 on test 0.158
# Finished epoch 13/200, latest loss 62.032, R^2 on test 0.460
# Finished epoch 14/200, latest loss 15.605, R^2 on test 0.306
# Finished epoch 15/200, latest loss 32.463, R^2 on test 0.319
# Finished epoch 16/200, latest loss 42.304, R^2 on test 0.206
# Finished epoch 17/200, latest loss 53.355, R^2 on test 0.420
# Finished epoch 18/200, latest loss 15.479, R^2 on test 0.532
# Finished epoch 19/200, latest loss 58.473, R^2 on test 0.364
# Finished epoch 20/200, latest loss 27.215, R^2 on test 0.505
# Finished epoch 21/200, latest loss 15.132, R^2 on test 0.529
# Finished epoch 22/200, latest loss 1.635, R^2 on test 0.272
# Finished epoch 23/200, latest loss 47.452, R^2 on test 0.546
# Finished epoch 24/200, latest loss 27.193, R^2 on test 0.539
# Finished epoch 25/200, latest loss 6.710, R^2 on test 0.605
# Finished epoch 26/200, latest loss 33.799, R^2 on test 0.481
# Finished epoch 27/200, latest loss 12.083, R^2 on test 0.574
# Finished epoch 28/200, latest loss 52.870, R^2 on test 0.565
# Finished epoch 29/200, latest loss 40.164, R^2 on test 0.697
# Finished epoch 30/200, latest loss 22.113, R^2 on test 0.649
# Finished epoch 31/200, latest loss 15.890, R^2 on test 0.571
# Finished epoch 32/200, latest loss 13.314, R^2 on test 0.674
# Finished epoch 33/200, latest loss 21.963, R^2 on test 0.654
# Finished epoch 34/200, latest loss 27.550, R^2 on test 0.580
# Finished epoch 35/200, latest loss 18.045, R^2 on test 0.596
# Finished epoch 36/200, latest loss 63.061, R^2 on test 0.679
# Finished epoch 37/200, latest loss 31.018, R^2 on test 0.670
# Finished epoch 38/200, latest loss 19.040, R^2 on test 0.746
# Finished epoch 39/200, latest loss 21.751, R^2 on test 0.723
# Finished epoch 40/200, latest loss 22.869, R^2 on test 0.739
# Finished epoch 41/200, latest loss 31.309, R^2 on test 0.759
# Finished epoch 42/200, latest loss 13.253, R^2 on test 0.668
# Finished epoch 43/200, latest loss 50.950, R^2 on test 0.727
# Finished epoch 44/200, latest loss 16.862, R^2 on test 0.751
# Finished epoch 45/200, latest loss 7.048, R^2 on test 0.660
# Finished epoch 46/200, latest loss 14.850, R^2 on test 0.603
# Finished epoch 47/200, latest loss 19.243, R^2 on test 0.695
# Finished epoch 48/200, latest loss 33.288, R^2 on test 0.752
# Finished epoch 49/200, latest loss 8.831, R^2 on test 0.691
# Finished epoch 50/200, latest loss 14.432, R^2 on test 0.693
# Finished epoch 51/200, latest loss 23.884, R^2 on test 0.771
# Finished epoch 52/200, latest loss 36.083, R^2 on test 0.770
# Finished epoch 53/200, latest loss 28.995, R^2 on test 0.676
# Finished epoch 54/200, latest loss 16.045, R^2 on test 0.681
# Finished epoch 55/200, latest loss 7.507, R^2 on test 0.764
# Finished epoch 56/200, latest loss 13.297, R^2 on test 0.746
# Finished epoch 57/200, latest loss 2.296, R^2 on test 0.757
# Finished epoch 58/200, latest loss 14.578, R^2 on test 0.723
# Finished epoch 59/200, latest loss 11.384, R^2 on test 0.802
# Finished epoch 60/200, latest loss 48.238, R^2 on test 0.851
# Finished epoch 61/200, latest loss 7.540, R^2 on test 0.778
# Finished epoch 62/200, latest loss 13.447, R^2 on test 0.704
# Finished epoch 63/200, latest loss 13.845, R^2 on test 0.745
# Finished epoch 64/200, latest loss 15.072, R^2 on test 0.753
# Finished epoch 65/200, latest loss 6.472, R^2 on test 0.828
# Finished epoch 66/200, latest loss 13.211, R^2 on test 0.798
# Finished epoch 67/200, latest loss 10.773, R^2 on test 0.760
# Finished epoch 68/200, latest loss 0.875, R^2 on test 0.785
# Finished epoch 69/200, latest loss 10.534, R^2 on test 0.785
# Finished epoch 70/200, latest loss 9.326, R^2 on test 0.816
# Finished epoch 71/200, latest loss 17.935, R^2 on test 0.820
# Finished epoch 72/200, latest loss 19.031, R^2 on test 0.778
# Finished epoch 73/200, latest loss 10.314, R^2 on test 0.867
# Finished epoch 74/200, latest loss 20.774, R^2 on test 0.789
# Finished epoch 75/200, latest loss 20.721, R^2 on test 0.776
# Finished epoch 76/200, latest loss 15.366, R^2 on test 0.760
# Finished epoch 77/200, latest loss 10.671, R^2 on test 0.767
# Finished epoch 78/200, latest loss 1.852, R^2 on test 0.795
# Finished epoch 79/200, latest loss 10.807, R^2 on test 0.868
# Finished epoch 80/200, latest loss 30.016, R^2 on test 0.778
# Finished epoch 81/200, latest loss 9.132, R^2 on test 0.832
# Finished epoch 82/200, latest loss 9.246, R^2 on test 0.821
# Finished epoch 83/200, latest loss 3.470, R^2 on test 0.757
# Finished epoch 84/200, latest loss 22.594, R^2 on test 0.827
# Finished epoch 85/200, latest loss 30.268, R^2 on test 0.772
# Finished epoch 86/200, latest loss 20.643, R^2 on test 0.805
# Finished epoch 87/200, latest loss 11.056, R^2 on test 0.859
# Finished epoch 88/200, latest loss 15.876, R^2 on test 0.835
# Finished epoch 89/200, latest loss 10.848, R^2 on test 0.760
# Finished epoch 90/200, latest loss 7.587, R^2 on test 0.749
# Finished epoch 91/200, latest loss 2.292, R^2 on test 0.808
# Finished epoch 92/200, latest loss 8.649, R^2 on test 0.770
# Finished epoch 93/200, latest loss 10.881, R^2 on test 0.801
# Finished epoch 94/200, latest loss 8.617, R^2 on test 0.813
# Finished epoch 95/200, latest loss 9.008, R^2 on test 0.765
# Finished epoch 96/200, latest loss 2.087, R^2 on test 0.781
# Finished epoch 97/200, latest loss 3.732, R^2 on test 0.772
# Finished epoch 98/200, latest loss 41.917, R^2 on test 0.856
# Finished epoch 99/200, latest loss 3.565, R^2 on test 0.830
# Finished epoch 100/200, latest loss 15.017, R^2 on test 0.761
# Finished epoch 101/200, latest loss 7.607, R^2 on test 0.845
# Finished epoch 102/200, latest loss 18.674, R^2 on test 0.805
# Finished epoch 103/200, latest loss 12.780, R^2 on test 0.834
# Finished epoch 104/200, latest loss 10.280, R^2 on test 0.862
# Finished epoch 105/200, latest loss 7.260, R^2 on test 0.819
# Finished epoch 106/200, latest loss 3.996, R^2 on test 0.795
# Finished epoch 107/200, latest loss 6.101, R^2 on test 0.778
# Finished epoch 108/200, latest loss 6.715, R^2 on test 0.880
# Finished epoch 109/200, latest loss 4.383, R^2 on test 0.884
# Finished epoch 110/200, latest loss 5.992, R^2 on test 0.846
# Finished epoch 111/200, latest loss 7.785, R^2 on test 0.882
# Finished epoch 112/200, latest loss 13.581, R^2 on test 0.813
# Finished epoch 113/200, latest loss 3.483, R^2 on test 0.771
# Finished epoch 114/200, latest loss 11.353, R^2 on test 0.826
# Finished epoch 115/200, latest loss 10.357, R^2 on test 0.829
# Finished epoch 116/200, latest loss 10.829, R^2 on test 0.864
# Finished epoch 117/200, latest loss 4.743, R^2 on test 0.846
# Finished epoch 118/200, latest loss 21.227, R^2 on test 0.835
# Finished epoch 119/200, latest loss 15.160, R^2 on test 0.807
# Finished epoch 120/200, latest loss 8.965, R^2 on test 0.812
# Finished epoch 121/200, latest loss 12.641, R^2 on test 0.813
# Finished epoch 122/200, latest loss 6.366, R^2 on test 0.775
# Finished epoch 123/200, latest loss 4.137, R^2 on test 0.804
# Finished epoch 124/200, latest loss 7.800, R^2 on test 0.853
# Finished epoch 125/200, latest loss 14.342, R^2 on test 0.760
# Finished epoch 126/200, latest loss 5.475, R^2 on test 0.843
# Finished epoch 127/200, latest loss 7.991, R^2 on test 0.809
# Finished epoch 128/200, latest loss 6.552, R^2 on test 0.849
# Finished epoch 129/200, latest loss 7.178, R^2 on test 0.849
# Finished epoch 130/200, latest loss 3.711, R^2 on test 0.825
# Finished epoch 131/200, latest loss 4.970, R^2 on test 0.842
# Finished epoch 132/200, latest loss 0.307, R^2 on test 0.860
# Finished epoch 133/200, latest loss 4.700, R^2 on test 0.704
# Finished epoch 134/200, latest loss 13.381, R^2 on test 0.857
# Finished epoch 135/200, latest loss 4.671, R^2 on test 0.835
# Finished epoch 136/200, latest loss 4.188, R^2 on test 0.784
# Finished epoch 137/200, latest loss 11.718, R^2 on test 0.846
# Finished epoch 138/200, latest loss 6.607, R^2 on test 0.861
# Finished epoch 139/200, latest loss 9.281, R^2 on test 0.882
# Finished epoch 140/200, latest loss 14.361, R^2 on test 0.822
# Finished epoch 141/200, latest loss 8.085, R^2 on test 0.853
# Finished epoch 142/200, latest loss 2.962, R^2 on test 0.824
# Finished epoch 143/200, latest loss 4.848, R^2 on test 0.863
# Finished epoch 144/200, latest loss 5.651, R^2 on test 0.850
# Finished epoch 145/200, latest loss 4.016, R^2 on test 0.821
# Finished epoch 146/200, latest loss 8.304, R^2 on test 0.837
# Finished epoch 147/200, latest loss 10.060, R^2 on test 0.839
# Finished epoch 148/200, latest loss 4.628, R^2 on test 0.881
# Finished epoch 149/200, latest loss 4.765, R^2 on test 0.852
# Finished epoch 150/200, latest loss 6.656, R^2 on test 0.754
# Finished epoch 151/200, latest loss 2.410, R^2 on test 0.820
# Finished epoch 152/200, latest loss 19.675, R^2 on test 0.789
# Finished epoch 153/200, latest loss 15.593, R^2 on test 0.871
# Finished epoch 154/200, latest loss 9.907, R^2 on test 0.830
# Finished epoch 155/200, latest loss 8.700, R^2 on test 0.823
# Finished epoch 156/200, latest loss 6.054, R^2 on test 0.874
# Finished epoch 157/200, latest loss 1.641, R^2 on test 0.864
# Finished epoch 158/200, latest loss 9.143, R^2 on test 0.829
# Finished epoch 159/200, latest loss 6.083, R^2 on test 0.886
# Finished epoch 160/200, latest loss 12.906, R^2 on test 0.911
# Finished epoch 161/200, latest loss 11.301, R^2 on test 0.872
# Finished epoch 162/200, latest loss 12.347, R^2 on test 0.891
# Finished epoch 163/200, latest loss 20.688, R^2 on test 0.845
# Finished epoch 164/200, latest loss 19.707, R^2 on test 0.835
# Finished epoch 165/200, latest loss 2.440, R^2 on test 0.863
# Finished epoch 166/200, latest loss 5.799, R^2 on test 0.840
# Finished epoch 167/200, latest loss 2.608, R^2 on test 0.853
# Finished epoch 168/200, latest loss 5.649, R^2 on test 0.860
# Finished epoch 169/200, latest loss 4.197, R^2 on test 0.879
# Finished epoch 170/200, latest loss 2.780, R^2 on test 0.810
# Finished epoch 171/200, latest loss 13.299, R^2 on test 0.812
# Finished epoch 172/200, latest loss 3.085, R^2 on test 0.868
# Finished epoch 173/200, latest loss 12.729, R^2 on test 0.828
# Finished epoch 174/200, latest loss 9.383, R^2 on test 0.807
# Finished epoch 175/200, latest loss 5.696, R^2 on test 0.865
# Finished epoch 176/200, latest loss 8.426, R^2 on test 0.808
# Finished epoch 177/200, latest loss 0.483, R^2 on test 0.814
# Finished epoch 178/200, latest loss 9.481, R^2 on test 0.829
# Finished epoch 179/200, latest loss 2.796, R^2 on test 0.825
# Finished epoch 180/200, latest loss 7.293, R^2 on test 0.836
# Finished epoch 181/200, latest loss 5.093, R^2 on test 0.859
# Finished epoch 182/200, latest loss 4.615, R^2 on test 0.892
# Finished epoch 183/200, latest loss 16.742, R^2 on test 0.849
# Finished epoch 184/200, latest loss 5.234, R^2 on test 0.875
# Finished epoch 185/200, latest loss 10.017, R^2 on test 0.867
# Finished epoch 186/200, latest loss 15.021, R^2 on test 0.852
# Finished epoch 187/200, latest loss 16.009, R^2 on test 0.853
# Finished epoch 188/200, latest loss 9.393, R^2 on test 0.914
# Finished epoch 189/200, latest loss 1.811, R^2 on test 0.872
# Finished epoch 190/200, latest loss 10.453, R^2 on test 0.817
# Finished epoch 191/200, latest loss 7.574, R^2 on test 0.901
# Finished epoch 192/200, latest loss 14.886, R^2 on test 0.851
# Finished epoch 193/200, latest loss 0.323, R^2 on test 0.778
# Finished epoch 194/200, latest loss 15.044, R^2 on test 0.794
# Finished epoch 195/200, latest loss 15.625, R^2 on test 0.806
# Finished epoch 196/200, latest loss 8.085, R^2 on test 0.786
# Finished epoch 197/200, latest loss 3.918, R^2 on test 0.865
# Finished epoch 198/200, latest loss 8.355, R^2 on test 0.857
# Finished epoch 199/200, latest loss 7.620, R^2 on test 0.814
# Finished epoch 200/200, latest loss 5.749, R^2 on test 0.870
